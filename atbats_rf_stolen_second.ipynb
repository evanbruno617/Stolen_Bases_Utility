# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize
from matplotlib import pyplot as plt
import ast
import joblib

# %%
first_base = pd.read_csv('atbats_second_solo.csv')

first_base
# Out:
#        Unnamed: 0        Batter_name  Rbi_outcome  Rbi_stay  Success_steal  \
# 0               0    Jacoby Ellsbury            1         0           0.45
# 1               1   Charlie Blackmon            1         0           0.50
# 2               2    Jacoby Ellsbury            1         1           0.45
# 3               3    Jacoby Ellsbury            1         0           0.45
# 4               4       Justin Upton            0         0           0.35
# ...           ...                ...          ...       ...            ...
# 69450       69450  Francisco Alvarez            1         1           0.30
# 69451       69451     Ramón Laureano            1         0           0.30
# 69452       69452    Travis d'Arnaud            1         0           0.15
# 69453       69453        Gio Urshela            1         1           0.15
# 69454       69454     Ramón Laureano            0         0           0.30
#
#        Success_stay  Outs  homeScore  awayScore  inning  isTopInning  Isout  \
# 0              0.15     2          3          4       8        False   True
# 1              0.15     3          0          0       3         True   True
# 2              0.15     2          0          0       3         True  False
# 3              0.15     2          0          0       1         True   True
# 4              0.05     1          0          1       1         True  False
# ...             ...   ...        ...        ...     ...          ...    ...
# 69450          0.30     0          3          1       8         True  False
# 69451          0.15     2          1          0       6        False   True
# 69452          0.15     3          7          8       9        False   True
# 69453          0.15     1          1          0       2        False  False
# 69454          0.15     1          0          0       2        False   True
#
#        Current_outs            dict_players        Date
# 0                 1  {'init': 0, 458731: 2}  2014-07-27
# 1                 1  {'init': 0, 592710: 2}  2014-08-01
# 2                 2  {'init': 0, 458731: 2}  2014-08-01
# 3                 1  {'init': 0, 458731: 2}  2014-08-01
# 4                 1  {'init': 0, 518692: 2}  2014-08-02
# ...             ...                     ...         ...
# 69450             0  {'init': 0, 621438: 2}  2024-09-30
# 69451             1  {'init': 0, 624585: 2}  2024-09-30
# 69452             1  {'init': 0, 642201: 2}  2024-09-30
# 69453             1  {'init': 0, 624585: 2}  2024-09-30
# 69454             1  {'init': 0, 624585: 2}  2024-09-30
#
# [69455 rows x 15 columns]

# %%
list(ast.literal_eval(first_base['dict_players'].tolist()[0]).keys())
# Out:
# ['init', 458731]

# %%
first_base['runner_id'] = first_base['dict_players'].apply(lambda x: list(ast.literal_eval(x).keys())[-1])

# %%
first_base.head()
# Out:
#    Unnamed: 0       Batter_name  Rbi_outcome  Rbi_stay  Success_steal  \
# 0           0   Jacoby Ellsbury            1         0           0.45
# 1           1  Charlie Blackmon            1         0           0.50
# 2           2   Jacoby Ellsbury            1         1           0.45
# 3           3   Jacoby Ellsbury            1         0           0.45
# 4           4      Justin Upton            0         0           0.35
#
#    Success_stay  Outs  homeScore  awayScore  inning  isTopInning  Isout  \
# 0          0.15     2          3          4       8        False   True
# 1          0.15     3          0          0       3         True   True
# 2          0.15     2          0          0       3         True  False
# 3          0.15     2          0          0       1         True   True
# 4          0.05     1          0          1       1         True  False
#
#    Current_outs            dict_players        Date  runner_id
# 0             1  {'init': 0, 458731: 2}  2014-07-27     458731
# 1             1  {'init': 0, 592710: 2}  2014-08-01     592710
# 2             2  {'init': 0, 458731: 2}  2014-08-01     458731
# 3             1  {'init': 0, 458731: 2}  2014-08-01     458731
# 4             1  {'init': 0, 518692: 2}  2014-08-02     518692

# %%
first_base
# Out:
#        Unnamed: 0        Batter_name  Rbi_outcome  Rbi_stay  Success_steal  \
# 0               0    Jacoby Ellsbury            1         0           0.45
# 1               1   Charlie Blackmon            1         0           0.50
# 2               2    Jacoby Ellsbury            1         1           0.45
# 3               3    Jacoby Ellsbury            1         0           0.45
# 4               4       Justin Upton            0         0           0.35
# ...           ...                ...          ...       ...            ...
# 69450       69450  Francisco Alvarez            1         1           0.30
# 69451       69451     Ramón Laureano            1         0           0.30
# 69452       69452    Travis d'Arnaud            1         0           0.15
# 69453       69453        Gio Urshela            1         1           0.15
# 69454       69454     Ramón Laureano            0         0           0.30
#
#        Success_stay  Outs  homeScore  awayScore  inning  isTopInning  Isout  \
# 0              0.15     2          3          4       8        False   True
# 1              0.15     3          0          0       3         True   True
# 2              0.15     2          0          0       3         True  False
# 3              0.15     2          0          0       1         True   True
# 4              0.05     1          0          1       1         True  False
# ...             ...   ...        ...        ...     ...          ...    ...
# 69450          0.30     0          3          1       8         True  False
# 69451          0.15     2          1          0       6        False   True
# 69452          0.15     3          7          8       9        False   True
# 69453          0.15     1          1          0       2        False  False
# 69454          0.15     1          0          0       2        False   True
#
#        Current_outs            dict_players        Date  runner_id
# 0                 1  {'init': 0, 458731: 2}  2014-07-27     458731
# 1                 1  {'init': 0, 592710: 2}  2014-08-01     592710
# 2                 2  {'init': 0, 458731: 2}  2014-08-01     458731
# 3                 1  {'init': 0, 458731: 2}  2014-08-01     458731
# 4                 1  {'init': 0, 518692: 2}  2014-08-02     518692
# ...             ...                     ...         ...        ...
# 69450             0  {'init': 0, 621438: 2}  2024-09-30     621438
# 69451             1  {'init': 0, 624585: 2}  2024-09-30     624585
# 69452             1  {'init': 0, 642201: 2}  2024-09-30     642201
# 69453             1  {'init': 0, 624585: 2}  2024-09-30     624585
# 69454             1  {'init': 0, 624585: 2}  2024-09-30     624585
#
# [69455 rows x 16 columns]

# %%
stolen_df = pd.read_csv('stolen_df_2.csv')
stolen_df
# Out:
#        Result Exchange Arm_Strength  Sprint        Date  runner_id  \
# 0           1     0.74         84.9    28.0  2021-04-01     545341
# 1           0     0.75         81.4    27.3  2021-04-01     643565
# 2           0     0.75         81.4    27.3  2021-04-01     643565
# 3           0     0.73         79.0    27.9  2020-09-30     666185
# 4           1      0.7         83.2    27.8  2020-09-30     502054
# ...       ...      ...          ...     ...         ...        ...
# 37567       1     0.65         82.7    27.6  2016-04-09     500871
# 37568       1     0.75         80.1    28.4  2016-04-09     514888
# 37569       1     0.75         80.1    28.0  2016-04-09     543807
# 37570       1     0.65         82.7    27.1  2016-04-08     572821
# 37571       1     0.67         81.2    28.0  2016-04-02     485567
#
#             runner_name  Result_1  Exchange_1  Arm_Strength_1  ...  \
# 0        Randal Grichuk         1        0.74            84.9  ...
# 1         Mike Tauchman         0        0.75            81.4  ...
# 2         Mike Tauchman         0        0.75            81.4  ...
# 3         Dylan Carlson         0        0.73            79.0  ...
# 4            Tommy Pham         1        0.70            83.2  ...
# ...                 ...       ...         ...             ...  ...
# 37567   Eduardo Escobar         1        0.65            82.7  ...
# 37568       Jose Altuve         1        0.75            80.1  ...
# 37569   George Springer         1        0.75            80.1  ...
# 37570      Brian Dozier         1        0.65            82.7  ...
# 37571  Ezequiel Carrera         1        0.67            81.2  ...
#
#        Arm_Strength_3  Sprint_3  Result_4  Exchange_4  Arm_Strength_4  \
# 0                84.9      27.0         0        0.74            84.9
# 1                81.4       NaN         1        0.75            81.4
# 2                81.4       NaN         1        0.75            81.4
# 3                79.0      27.6         1        0.73            79.0
# 4                83.2       NaN         1        0.70            83.2
# ...               ...       ...       ...         ...             ...
# 37567            82.7      25.2         0        0.65            82.7
# 37568            80.1      26.3         1        0.75            80.1
# 37569            80.1      26.3         1        0.75            80.1
# 37570            82.7       NaN         1        0.65            82.7
# 37571            81.2       NaN         1        0.67            81.2
#
#        Sprint_4  Result_5  Exchange_5  Arm_Strength_5  Sprint_5
# 0          27.7         0        0.74            84.9      25.0
# 1          30.5         1        0.75            81.4       NaN
# 2          30.5         1        0.75            81.4       NaN
# 3          27.6         0        0.73            79.0      28.6
# 4           NaN         1        0.70            83.2      27.4
# ...         ...       ...         ...             ...       ...
# 37567       NaN         1        0.65            82.7       NaN
# 37568      27.9         0        0.75            80.1      26.3
# 37569      27.9         0        0.75            80.1      26.3
# 37570      27.3         1        0.65            82.7       NaN
# 37571       NaN         0        0.67            81.2       NaN
#
# [37572 rows x 27 columns]

# %%
first_base = first_base.loc[first_base['Date'] > '2022-09-30']

# %%
stolen_df.sort_values(by='Date')
# Out:
#        Result Exchange Arm_Strength  Sprint        Date  runner_id  \
# 37571       1     0.67         81.2    28.0  2016-04-02     485567
# 32330       1     0.67         81.2    28.0  2016-04-02     485567
# 26536       1     0.67         81.2    28.0  2016-04-02     485567
# 32329       1     0.65         82.7    27.1  2016-04-08     572821
# 37570       1     0.65         82.7    27.1  2016-04-08     572821
# ...       ...      ...          ...     ...         ...        ...
# 26541       1     0.78         84.6    26.6  2023-09-30     666971
# 26540       1     0.62         83.5    26.0  2023-09-30     663656
# 26539       1     0.69         78.8    29.3  2023-09-30     686668
# 26537       1     0.72         83.7    29.4  2023-09-30     665923
# 9646        0      0.7         76.0    28.0  2023-09-30     642731
#
#                runner_name  Result_1  Exchange_1  Arm_Strength_1  ...  \
# 37571     Ezequiel Carrera         1        0.67            81.2  ...
# 32330     Ezequiel Carrera         1        0.67            81.2  ...
# 26536     Ezequiel Carrera         1        0.67            81.2  ...
# 32329         Brian Dozier         1        0.65            82.7  ...
# 37570         Brian Dozier         1        0.65            82.7  ...
# ...                    ...       ...         ...             ...  ...
# 26541  Lourdes Gurriel Jr.         1        0.69            85.4  ...
# 26540          Kyle Tucker         1        0.62            83.5  ...
# 26539        Brenton Doyle         1        0.60            79.5  ...
# 26537         Esteury Ruiz         1        0.72            83.7  ...
# 9646        Thairo Estrada         1        0.58            75.9  ...
#
#        Arm_Strength_3  Sprint_3  Result_4  Exchange_4  Arm_Strength_4  \
# 37571            81.2       NaN         1        0.67            81.2
# 32330            81.2       NaN         1        0.67            81.2
# 26536            81.2       NaN         1        0.67            81.2
# 32329            82.7       NaN         1        0.65            82.7
# 37570            82.7       NaN         1        0.65            82.7
# ...               ...       ...       ...         ...             ...
# 26541            85.4       NaN         1        0.69            85.4
# 26540            83.5      29.3         1        0.62            83.5
# 26539            79.5      29.6         1        0.60            79.5
# 26537            83.7       NaN         1        0.72            83.7
# 9646             75.9       NaN         1        0.58            75.9
#
#        Sprint_4  Result_5  Exchange_5  Arm_Strength_5  Sprint_5
# 37571       NaN         0        0.67            81.2       NaN
# 32330       NaN         0        0.67            81.2       NaN
# 26536       NaN         0        0.67            81.2       NaN
# 32329      27.3         1        0.65            82.7       NaN
# 37570      27.3         1        0.65            82.7       NaN
# ...         ...       ...         ...             ...       ...
# 26541       NaN         1        0.69            85.4      29.6
# 26540      28.5         0        0.62            83.5      27.7
# 26539      27.1         0        0.60            79.5      29.2
# 26537      28.1         1        0.72            83.7      27.2
# 9646        NaN         1        0.58            75.9       NaN
#
# [37572 rows x 27 columns]

# %%
data_exp = {
    "Runners": ['0', "1", "2", "1,2", "3", "1,3", "2,3", "1,2,3"],
    "0 Outs": [0.461, 0.831, 1.068, 1.373, 1.426, 1.798, 1.920, 2.282],
    "1 Outs": [0.243, 0.489, 0.644, 0.908, 0.865, 1.140, 1.352, 1.520],
    "2 Outs": [0.095, 0.214, 0.305, 0.343, 0.413, 0.471, 0.570, 0.736],
}


exp_run_base = pd.DataFrame(data_exp)
exp_run_base
# Out:
#   Runners  0 Outs  1 Outs  2 Outs
# 0       0   0.461   0.243   0.095
# 1       1   0.831   0.489   0.214
# 2       2   1.068   0.644   0.305
# 3     1,2   1.373   0.908   0.343
# 4       3   1.426   0.865   0.413
# 5     1,3   1.798   1.140   0.471
# 6     2,3   1.920   1.352   0.570
# 7   1,2,3   2.282   1.520   0.736

# %%
stolen_subset = stolen_df[['Result', 'Date', 'runner_id']]

final_df = pd.merge(stolen_df, first_base, on=['Date', 'runner_id'], how='inner')

final_df.replace(' --', 0, inplace=True)

# %%
final_df['Rbi_steal_unique'] = final_df.apply(lambda x: 1 if x['Rbi_outcome'] == 1 and x['Rbi_stay'] == 0 else 0, axis=1)
final_df.sort_values(by='Date')
# Out:
#      index  Result Exchange Arm_Strength  Sprint        Date  runner_id  \
# 325   2316       1     0.75         77.3    28.7  2023-04-02     676801
# 324   2318       1     0.75         77.3    28.7  2023-04-02     676801
# 287   2322       1     0.78         81.2    27.2  2023-04-02     502054
# 286   2324       1     0.78         81.2    27.2  2023-04-02     502054
# 279   2325       1     0.78         81.2    27.2  2023-04-02     502054
# ..     ...     ...      ...          ...     ...         ...        ...
# 578     16       1     0.78         84.6    29.6  2023-09-29     682998
# 579     14       1     0.78         84.6    29.6  2023-09-29     682998
# 580     12       1     0.78         84.6    29.6  2023-09-29     682998
# 391     40       1      0.8         81.7    29.7  2023-09-29     696285
# 169     25       1     0.62         83.5    27.1  2023-09-29     514888
#
#         runner_name  Result_1  Exchange_1  ...            dict_players  \
# 325  Chas McCormick         0        0.69  ...  {'init': 0, 676801: 2}
# 324  Chas McCormick         0        0.69  ...  {'init': 0, 676801: 2}
# 287      Tommy Pham         1        0.68  ...  {'init': 0, 502054: 2}
# 286      Tommy Pham         1        0.68  ...  {'init': 0, 502054: 2}
# 279      Tommy Pham         1        0.68  ...  {'init': 0, 502054: 2}
# ..              ...       ...         ...  ...                     ...
# 578  Corbin Carroll         1        0.69  ...  {'init': 0, 682998: 2}
# 579  Corbin Carroll         1        0.69  ...  {'init': 0, 682998: 2}
# 580  Corbin Carroll         1        0.69  ...  {'init': 0, 682998: 2}
# 391     Jacob Young         1        0.67  ...  {'init': 0, 696285: 2}
# 169     Jose Altuve         1        0.62  ...  {'init': 0, 514888: 2}
#
#      Past_Steal_Success  Simulated_out  Diff  Diff_transform  Utility_steal  \
# 325                   1              3    -3        0.135335        0.06195
# 324                   1              3    -3        0.135335        0.06195
# 287                   1              3     4        0.028566        0.20650
# 286                   1              3     4        0.028566        0.20650
# 279                   1              2     4        0.028566        0.34600
# ..                  ...            ...   ...             ...            ...
# 578                   1              2     0        1.000000        0.25950
# 579                   1              2     0        1.000000        0.25950
# 580                   1              2     0        1.000000        0.25950
# 391                   1              2    -2        0.411112        0.38925
# 169                   1              2     2        0.411112        0.12975
#
#      Utility_caught  Utility_stay  Expected_Utils  Rbi_steal_unique
# 325            -0.0       0.01525       -0.000929                 0
# 324            -0.0       0.01525       -0.000929                 0
# 287            -0.0       0.06100       -0.007457                 0
# 286            -0.0       0.06100       -0.007457                 0
# 279            -0.0       0.03220       -0.008210                 1
# ..              ...           ...             ...               ...
# 578            -0.0       0.06440        0.071773                 0
# 579            -0.0       0.06440        0.071773                 1
# 580            -0.0       0.06440        0.071773                 0
# 391            -0.0       0.12880        0.011487                 1
# 169            -0.0       0.19320       -0.051451                 1
#
# [652 rows x 51 columns]

# %%
X_scaler = joblib.load('gradient_scale.pkl')

nn_model = joblib.load('gradient.pkl')

# %%
final_df.dropna(inplace=True)

# %%
X = final_df[['Exchange', 'Arm_Strength', 'Sprint', 'Result_1', 'Exchange_1',
       'Arm_Strength_1', 'Sprint_1', 'Result_2', 'Exchange_2',
       'Arm_Strength_2', 'Sprint_2', 'Result_3', 'Exchange_3',
       'Arm_Strength_3', 'Sprint_3', 'Result_4', 'Exchange_4',
       'Arm_Strength_4', 'Sprint_4', 'Result_5', 'Exchange_5',
       'Arm_Strength_5', 'Sprint_5']]



X_scaled = X_scaler.transform(X)

predictions = nn_model.predict(X_scaled)

final_df['Past_Steal_Success'] = predictions

# %%
final_df['Simulated_out'] = final_df['Current_outs'] + 1

# %%
def utility_steal(x):
    
    if x["Current_outs"] in [0, 1]:
        
        utils = x['Past_Steal_Success'] * x['Success_steal'] * (exp_run_base.loc[(exp_run_base['Runners'] == "3")][f'{x["Current_outs"]} Out'].tolist()[0])
                                                                
    else:
        utils = x['Past_Steal_Success'] * x['Success_steal'] * (exp_run_base.loc[(exp_run_base['Runners'] == "3")][f'{x["Current_outs"]} Outs'].tolist()[0])
          
    return utils
                                                                
def utility_caught(x):
    
    if x["Simulated_out"] in [1, 2]:
        
        utils = (1 - x['Past_Steal_Success']) * (exp_run_base.loc[(exp_run_base['Runners'] == "0")][f'{x["Simulated_out"]} Outs'].tolist()[0] - exp_run_base.loc[(exp_run_base['Runners'] == "2")][f'{x["Current_outs"]} Out'].tolist()[0])
                                                                
    else:
        utils = (1 - x['Past_Steal_Success']) * (exp_run_base.loc[(exp_run_base['Runners'] == "0")][f'{x["Simulated_out"]} Outs'].tolist()[0] - exp_run_base.loc[(exp_run_base['Runners'] == "2")][f'{x["Current_outs"]} Outs'].tolist()[0]) 
          
    return utils
                                                 
def utility_stay(x):
    
    if x["Current_outs"] in [0, 1]:
        
        utils = (x['Success_stay']) * (exp_run_base.loc[(exp_run_base['Runners'] == "2")][f'{x["Current_outs"]} Out'].tolist()[0])

                                                                
    else:
        utils = (x['Success_stay']) * (exp_run_base.loc[(exp_run_base['Runners'] == "2")][f'{x["Current_outs"]} Out'].tolist()[0])
          
    return utils

# %%
final_df['Diff'] = final_df.apply(lambda x: x['awayScore'] - x['homeScore'] if x['isTopInning'] == 1 else x['homeScore'] - x['awayScore'], axis=1)


final_df['Diff_transform'] = final_df['Diff'].apply(lambda x: np.exp(-(x**2) / (2 * (1.5)**2)))

final_df['Utility_steal'] = final_df.apply(lambda x: x['Past_Steal_Success'] * x['Success_steal'] * (exp_run_base.loc[(exp_run_base['Runners'] == "3")][f'{x["Current_outs"]} Outs'].tolist()[0]), axis=1)

final_df['Utility_caught'] = final_df.apply(lambda x: (1 - x['Past_Steal_Success']) * (0 - exp_run_base.loc[(exp_run_base['Runners'] == "2")][f'{x["Current_outs"]} Outs'].tolist()[0]) if x["Simulated_out"] == 3 else (1 - x['Past_Steal_Success']) * (exp_run_base.loc[(exp_run_base['Runners'] == "0")][f'{x["Simulated_out"]} Outs'].tolist()[0] - exp_run_base.loc[(exp_run_base['Runners'] == "2")][f'{x["Current_outs"]} Outs'].tolist()[0]), axis=1)

final_df['Utility_stay'] = final_df.apply(lambda x: (x['Success_stay']) * (exp_run_base.loc[(exp_run_base['Runners'] == "2")][f'{x["Current_outs"]} Outs'].tolist()[0]), axis=1)

# %%
final_df
# Out:
#       Result Exchange Arm_Strength  Sprint        Date  runner_id  \
# 8          1     0.78         84.6    29.6  2023-09-29     682998
# 9          1     0.78         84.6    29.6  2023-09-29     682998
# 10         1     0.78         84.6    29.6  2023-09-29     682998
# 11         1     0.78         84.6    29.6  2023-09-29     682998
# 12         1     0.78         84.6    29.6  2023-09-29     682998
# ...      ...      ...          ...     ...         ...        ...
# 2319       1     0.75         77.3    28.7  2023-04-02     676801
# 2322       1     0.78         81.2    27.2  2023-04-02     502054
# 2323       1     0.78         81.2    27.2  2023-04-02     502054
# 2324       1     0.78         81.2    27.2  2023-04-02     502054
# 2325       1     0.78         81.2    27.2  2023-04-02     502054
#
#          runner_name  Result_1  Exchange_1  Arm_Strength_1  ...  Isout  \
# 8     Corbin Carroll         1        0.69            85.4  ...  False
# 9     Corbin Carroll         1        0.69            85.4  ...   True
# 10    Corbin Carroll         1        0.69            85.4  ...   True
# 11    Corbin Carroll         1        0.69            85.4  ...   True
# 12    Corbin Carroll         1        0.69            85.4  ...  False
# ...              ...       ...         ...             ...  ...    ...
# 2319  Chas McCormick         0        0.69            77.8  ...  False
# 2322      Tommy Pham         1        0.68            82.2  ...  False
# 2323      Tommy Pham         1        0.68            82.2  ...   True
# 2324      Tommy Pham         1        0.68            82.2  ...  False
# 2325      Tommy Pham         1        0.68            82.2  ...   True
#
#       Current_outs            dict_players  Past_Steal_Success  Simulated_out  \
# 8                1  {'init': 0, 682998: 2}                   1              2
# 9                1  {'init': 0, 682998: 2}                   1              2
# 10               1  {'init': 0, 682998: 2}                   1              2
# 11               1  {'init': 0, 682998: 2}                   1              2
# 12               1  {'init': 0, 682998: 2}                   1              2
# ...            ...                     ...                 ...            ...
# 2319             2  {'init': 0, 676801: 2}                   1              3
# 2322             2  {'init': 0, 502054: 2}                   1              3
# 2323             1  {'init': 0, 502054: 2}                   1              2
# 2324             2  {'init': 0, 502054: 2}                   1              3
# 2325             1  {'init': 0, 502054: 2}                   1              2
#
#       Diff  Diff_transform  Utility_steal  Utility_caught  Utility_stay
# 8        0        1.000000        0.25950            -0.0       0.06440
# 9        0        1.000000        0.21625            -0.0       0.16100
# 10       0        1.000000        0.25950            -0.0       0.06440
# 11       0        1.000000        0.30275            -0.0       0.09660
# 12       0        1.000000        0.25950            -0.0       0.06440
# ...    ...             ...            ...             ...           ...
# 2319    -3        0.135335        0.06195            -0.0       0.01525
# 2322     4        0.028566        0.20650            -0.0       0.06100
# 2323     4        0.028566        0.34600            -0.0       0.03220
# 2324     4        0.028566        0.20650            -0.0       0.06100
# 2325     4        0.028566        0.34600            -0.0       0.03220
#
# [652 rows x 48 columns]

# %%
final_df.dropna(inplace=True)
final_df
# Out:
#       Result Exchange Arm_Strength  Sprint        Date  runner_id  \
# 8          1     0.78         84.6    29.6  2023-09-29     682998
# 9          1     0.78         84.6    29.6  2023-09-29     682998
# 10         1     0.78         84.6    29.6  2023-09-29     682998
# 11         1     0.78         84.6    29.6  2023-09-29     682998
# 12         1     0.78         84.6    29.6  2023-09-29     682998
# ...      ...      ...          ...     ...         ...        ...
# 2319       1     0.75         77.3    28.7  2023-04-02     676801
# 2322       1     0.78         81.2    27.2  2023-04-02     502054
# 2323       1     0.78         81.2    27.2  2023-04-02     502054
# 2324       1     0.78         81.2    27.2  2023-04-02     502054
# 2325       1     0.78         81.2    27.2  2023-04-02     502054
#
#          runner_name  Result_1  Exchange_1  Arm_Strength_1  ...  Isout  \
# 8     Corbin Carroll         1        0.69            85.4  ...  False
# 9     Corbin Carroll         1        0.69            85.4  ...   True
# 10    Corbin Carroll         1        0.69            85.4  ...   True
# 11    Corbin Carroll         1        0.69            85.4  ...   True
# 12    Corbin Carroll         1        0.69            85.4  ...  False
# ...              ...       ...         ...             ...  ...    ...
# 2319  Chas McCormick         0        0.69            77.8  ...  False
# 2322      Tommy Pham         1        0.68            82.2  ...  False
# 2323      Tommy Pham         1        0.68            82.2  ...   True
# 2324      Tommy Pham         1        0.68            82.2  ...  False
# 2325      Tommy Pham         1        0.68            82.2  ...   True
#
#       Current_outs            dict_players  Past_Steal_Success  Simulated_out  \
# 8                1  {'init': 0, 682998: 2}                   1              2
# 9                1  {'init': 0, 682998: 2}                   1              2
# 10               1  {'init': 0, 682998: 2}                   1              2
# 11               1  {'init': 0, 682998: 2}                   1              2
# 12               1  {'init': 0, 682998: 2}                   1              2
# ...            ...                     ...                 ...            ...
# 2319             2  {'init': 0, 676801: 2}                   1              3
# 2322             2  {'init': 0, 502054: 2}                   1              3
# 2323             1  {'init': 0, 502054: 2}                   1              2
# 2324             2  {'init': 0, 502054: 2}                   1              3
# 2325             1  {'init': 0, 502054: 2}                   1              2
#
#       Diff  Diff_transform  Utility_steal  Utility_caught  Utility_stay
# 8        0        1.000000        0.25950            -0.0       0.06440
# 9        0        1.000000        0.21625            -0.0       0.16100
# 10       0        1.000000        0.25950            -0.0       0.06440
# 11       0        1.000000        0.30275            -0.0       0.09660
# 12       0        1.000000        0.25950            -0.0       0.06440
# ...    ...             ...            ...             ...           ...
# 2319    -3        0.135335        0.06195            -0.0       0.01525
# 2322     4        0.028566        0.20650            -0.0       0.06100
# 2323     4        0.028566        0.34600            -0.0       0.03220
# 2324     4        0.028566        0.20650            -0.0       0.06100
# 2325     4        0.028566        0.34600            -0.0       0.03220
#
# [652 rows x 48 columns]

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

final_df['Diff_transform'] = final_df['Diff'].apply(lambda x: np.exp(-(x**2) / (2 * (1.5)**2)))

# %%
final_df['Expected_Utils'] = final_df['Utility_steal'] * final_df['Diff_transform'] * np.exp(-final_df['Current_outs']) + final_df['Utility_caught'] * np.exp(final_df['Current_outs']) * final_df['inning'] - final_df['Utility_stay'] * np.exp(-final_df['Current_outs'])

# %%
final_df
# Out:
#       Result Exchange Arm_Strength  Sprint        Date  runner_id  \
# 8          1     0.78         84.6    29.6  2023-09-29     682998
# 9          1     0.78         84.6    29.6  2023-09-29     682998
# 10         1     0.78         84.6    29.6  2023-09-29     682998
# 11         1     0.78         84.6    29.6  2023-09-29     682998
# 12         1     0.78         84.6    29.6  2023-09-29     682998
# ...      ...      ...          ...     ...         ...        ...
# 2319       1     0.75         77.3    28.7  2023-04-02     676801
# 2322       1     0.78         81.2    27.2  2023-04-02     502054
# 2323       1     0.78         81.2    27.2  2023-04-02     502054
# 2324       1     0.78         81.2    27.2  2023-04-02     502054
# 2325       1     0.78         81.2    27.2  2023-04-02     502054
#
#          runner_name  Result_1  Exchange_1  Arm_Strength_1  ...  Current_outs  \
# 8     Corbin Carroll         1        0.69            85.4  ...             1
# 9     Corbin Carroll         1        0.69            85.4  ...             1
# 10    Corbin Carroll         1        0.69            85.4  ...             1
# 11    Corbin Carroll         1        0.69            85.4  ...             1
# 12    Corbin Carroll         1        0.69            85.4  ...             1
# ...              ...       ...         ...             ...  ...           ...
# 2319  Chas McCormick         0        0.69            77.8  ...             2
# 2322      Tommy Pham         1        0.68            82.2  ...             2
# 2323      Tommy Pham         1        0.68            82.2  ...             1
# 2324      Tommy Pham         1        0.68            82.2  ...             2
# 2325      Tommy Pham         1        0.68            82.2  ...             1
#
#                 dict_players  Past_Steal_Success  Simulated_out  Diff  \
# 8     {'init': 0, 682998: 2}                   1              2     0
# 9     {'init': 0, 682998: 2}                   1              2     0
# 10    {'init': 0, 682998: 2}                   1              2     0
# 11    {'init': 0, 682998: 2}                   1              2     0
# 12    {'init': 0, 682998: 2}                   1              2     0
# ...                      ...                 ...            ...   ...
# 2319  {'init': 0, 676801: 2}                   1              3    -3
# 2322  {'init': 0, 502054: 2}                   1              3     4
# 2323  {'init': 0, 502054: 2}                   1              2     4
# 2324  {'init': 0, 502054: 2}                   1              3     4
# 2325  {'init': 0, 502054: 2}                   1              2     4
#
#       Diff_transform  Utility_steal  Utility_caught  Utility_stay  \
# 8           1.000000        0.25950            -0.0       0.06440
# 9           1.000000        0.21625            -0.0       0.16100
# 10          1.000000        0.25950            -0.0       0.06440
# 11          1.000000        0.30275            -0.0       0.09660
# 12          1.000000        0.25950            -0.0       0.06440
# ...              ...            ...             ...           ...
# 2319        0.135335        0.06195            -0.0       0.01525
# 2322        0.028566        0.20650            -0.0       0.06100
# 2323        0.028566        0.34600            -0.0       0.03220
# 2324        0.028566        0.20650            -0.0       0.06100
# 2325        0.028566        0.34600            -0.0       0.03220
#
#       Expected_Utils
# 8           0.071773
# 9           0.020325
# 10          0.071773
# 11          0.075838
# 12          0.071773
# ...              ...
# 2319       -0.000929
# 2322       -0.007457
# 2323       -0.008210
# 2324       -0.007457
# 2325       -0.008210
#
# [652 rows x 49 columns]

# %%
final_df = final_df.sort_values(by='Expected_Utils')
final_df = final_df.reset_index()

# %%
plt.scatter(x=final_df.index, y=final_df['Expected_Utils'])

# %%
# Above -1 util threshold

total_obs = len(final_df.loc[final_df['Expected_Utils'] > -1])
rbi_outcomes = final_df.loc[final_df['Expected_Utils'] > -1]['Rbi_steal_unique'].sum()
rbi_outcomes_stay = final_df.loc[final_df['Expected_Utils'] > -1]['Rbi_stay'].sum()
past_success_steal_prob = final_df.loc[final_df['Expected_Utils'] > -1]['Past_Steal_Success'].mean()

print(f'''Total Obs - {total_obs} with rbi outcomes - {rbi_outcomes} and prob of success of steal- {past_success_steal_prob} means that there is an  expected rbi return of {rbi_outcomes * past_success_steal_prob } this means you can expect a gain of {rbi_outcomes * past_success_steal_prob - rbi_outcomes_stay} RBis by choosing steal

With percentage of rbis gained per steal - {rbi_outcomes * past_success_steal_prob / total_obs}''')
# Out:
# Total Obs - 522 with rbi outcomes - 254 and prob of success of steal- 1.0 means that there is an  expected rbi return of 254.0 this means you can expect a gain of 160.0 RBis by choosing steal
#
# With percentage of rbis gained per steal - 0.48659003831417624

# %%
# Less than -1 threshold

total_obs = len(final_df.loc[final_df['Expected_Utils'] < -1])

rbi_outcomes = final_df.loc[final_df['Expected_Utils'] < -1]['Rbi_steal_unique'].sum()
rbi_outcomes_stay = final_df.loc[final_df['Expected_Utils'] < -1]['Rbi_stay'].sum()
past_success_steal_prob = final_df.loc[final_df['Expected_Utils'] < -1]['Past_Steal_Success'].mean()

print(f'''Total Obs - {total_obs} with rbi outcomes - {rbi_outcomes} and prob of success of steal- {past_success_steal_prob} means that there is an  expected rbi return of {rbi_outcomes * past_success_steal_prob } this means you can expect a gain of {rbi_outcomes * past_success_steal_prob - rbi_outcomes_stay} RBis by choosing steal or by choosing to stay gain {rbi_outcomes_stay} rbis

With percentage of rbis gained per steal - {rbi_outcomes * past_success_steal_prob / total_obs}''')
# Out:
# Total Obs - 130 with rbi outcomes - 46 and prob of success of steal- 0.0 means that there is an  expected rbi return of 0.0 this means you can expect a gain of -36.0 RBis by choosing steal or by choosing to stay gain 36 rbis
#
# With percentage of rbis gained per steal - 0.0

# %%
# accuracy out of sample 

true_acc = 0.94

# %%
# Above -1 util threshold

total_obs = len(final_df.loc[final_df['Expected_Utils'] > -1])
rbi_outcomes = final_df.loc[final_df['Expected_Utils'] > -1]['Rbi_steal_unique'].sum()
rbi_outcomes_stay = final_df.loc[final_df['Expected_Utils'] > -1]['Rbi_stay'].sum()
past_success_steal_prob = true_acc

print(f'''Total Obs - {total_obs} with rbi outcomes - {rbi_outcomes} and prob of success of steal- {past_success_steal_prob} means that there is an  expected rbi return of {rbi_outcomes * past_success_steal_prob } this means you can expect a gain of {rbi_outcomes * past_success_steal_prob - rbi_outcomes_stay} RBis by choosing steal

With percentage of rbis gained per attempted steal - {rbi_outcomes * past_success_steal_prob / total_obs}''')
# Out:
# Total Obs - 522 with rbi outcomes - 254 and prob of success of steal- 0.94 means that there is an  expected rbi return of 238.76 this means you can expect a gain of 144.76 RBis by choosing steal
#
# With percentage of rbis gained per attempted steal - 0.45739463601532565

# %%
# Less than -1 threshold

total_obs = len(final_df.loc[final_df['Expected_Utils'] < -1])

rbi_outcomes = final_df.loc[final_df['Expected_Utils'] < -1]['Rbi_steal_unique'].sum()
rbi_outcomes_stay = final_df.loc[final_df['Expected_Utils'] < -1]['Rbi_stay'].sum()
past_success_steal_prob = true_acc

print(f'''Total Obs - {total_obs} with rbi outcomes - {rbi_outcomes} and prob of success of steal- {past_success_steal_prob} means that there is an  expected rbi return of {rbi_outcomes * past_success_steal_prob } this means you can expect a gain of {rbi_outcomes * past_success_steal_prob - rbi_outcomes_stay} RBis by choosing steal or by choosing to stay gain {rbi_outcomes_stay} rbis

With percentage of rbis gained per attempted steal - {rbi_outcomes * past_success_steal_prob / total_obs}''')
# Out:
# Total Obs - 130 with rbi outcomes - 46 and prob of success of steal- 0.94 means that there is an  expected rbi return of 43.239999999999995 this means you can expect a gain of 7.239999999999995 RBis by choosing steal or by choosing to stay gain 36 rbis
#
# With percentage of rbis gained per attempted steal - 0.3326153846153846
