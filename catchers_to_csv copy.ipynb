# %%
import pandas as pd
import os

# %%
folder_path = '/Users/christsang/Desktop/mlb project/Sports/stolen_bases_new'

# %%
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/christsang/Desktop/mlb project/Sports/stolen_bases_new'

# %%
csv_files
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 csv_files
#
# NameError: name 'csv_files' is not defined

# %%
csv_list = []

for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    csv_list.append(df)

mlb_df = pd.concat(csv_list, ignore_index=True)
mlb_df.to_csv('combined.csv', index=False)

# %%
mlb_df.head()
# Out:
#   Unnamed: 0.1 Unnamed: 0 Start_Base End_Base           Event Respon_Pitcher  \
# 0            5          2         1B       2B  Stolen Base 2B            NaN
# 1            6         24         1B       2B  Stolen Base 2B            NaN
# 2            7         38         1B       2B  Stolen Base 2B            NaN
# 3            8         60         1B       2B  Stolen Base 2B            NaN
# 4            9         79         1B       2B  Stolen Base 2B            NaN
#
#   runner_id        runner_name           credit homeScore awayScore inning  \
# 0    122111     Gary Sheffield  A.J. Pierzynski         0         0      1
# 1    434158  Curtis Granderson  A.J. Pierzynski         1         0      3
# 2    430605        Ryan Raburn  A.J. Pierzynski         1         1      5
# 3    276547       Dewayne Wise       Dusty Ryan         2         2      6
# 4    434158  Curtis Granderson  A.J. Pierzynski         6         2      7
#
#   isTopInning        Date  Action Base  Year
# 0        True  2008-09-29  Stolen   2B  2008
# 1        True  2008-09-29  Stolen   2B  2008
# 2        True  2008-09-29  Stolen   2B  2008
# 3       False  2008-09-29  Stolen   2B  2008
# 4        True  2008-09-29  Stolen   2B  2008

# %%
mlb_df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Start_Base', 'End_Base', 'Event',
#        'Respon_Pitcher', 'runner_id', 'runner_name', 'credit', 'homeScore',
#        'awayScore', 'inning', 'isTopInning', 'Date', 'Action', 'Base', 'Year'],
#       dtype='object')

# %%
cleaned_mlb = mlb_df[[col for col in mlb_df.columns if col not in ['Unnamed: 0.1', 'Unnamed: 0',
                                                    'Respon_Pitcher']]]

# %%
cleaned_mlb.head()
# Out:
#   Start_Base End_Base           Event runner_id        runner_name  \
# 0         1B       2B  Stolen Base 2B    122111     Gary Sheffield
# 1         1B       2B  Stolen Base 2B    434158  Curtis Granderson
# 2         1B       2B  Stolen Base 2B    430605        Ryan Raburn
# 3         1B       2B  Stolen Base 2B    276547       Dewayne Wise
# 4         1B       2B  Stolen Base 2B    434158  Curtis Granderson
#
#             credit homeScore awayScore inning isTopInning        Date  Action  \
# 0  A.J. Pierzynski         0         0      1        True  2008-09-29  Stolen
# 1  A.J. Pierzynski         1         0      3        True  2008-09-29  Stolen
# 2  A.J. Pierzynski         1         1      5        True  2008-09-29  Stolen
# 3       Dusty Ryan         2         2      6       False  2008-09-29  Stolen
# 4  A.J. Pierzynski         6         2      7        True  2008-09-29  Stolen
#
#   Base  Year
# 0   2B  2008
# 1   2B  2008
# 2   2B  2008
# 3   2B  2008
# 4   2B  2008

# %%
cleaned_mlb['credit'].unique(), cleaned_mlb['credit'].nunique()
# Out:
# (array(['A.J. Pierzynski', 'Dusty Ryan', 'Kenji Johjima', 'Bengie Molina',
#         'Nick Hundley', 'Max Ramirez', 'John Buck', 'Kelly Shoppach',
#         'Clint Sammons', 'David Ross', 'Francisco Cervelli', 'Luke Montz',
#         'Lou Marson', 'Ramon Castro', 'Ryan Doumit', 'Taylor Teagarden',
#         'Russell Martin', 'Chris Snyder', 'Mark Johnson', 'Paul Bako',
#         'Michel Hernandez', 'Jason Kendall', 'Joe Mauer', 'John Baker',
#         'Steve Holm', 'Danny Ardoin', 'Kurt Suzuki', 'Jason LaRue',
#         'Humberto Quintero', 'Brian Schneider', 'Chad Moeller',
#         'George Kottaras', 'Dane Sardinha', 'Ronny Paulino', 'Brad Ausmus',
#         'Koyie Hill', 'Robinson Cancel', 'Dioner Navarro', 'Ryan Hanigan',
#         'Wil Nieves', 'Henry Blanco', 'Gregg Zaun', 'Carlos Ruiz',
#         'Brian McCann', 'Ramon Hernandez', 'Victor Martinez',
#         'Mike Napoli', 'Miguel Montero', 'Rob Bowen', 'Guillermo Quiroz',
#         'Rob Johnson', 'Gerald Laird', 'José Molina', 'Toby Hall',
#         'Curtis Thigpen', 'Chris Iannetta', 'Geovany Soto',
#         'Jason Varitek', 'Chris Coste', 'Ivan Rodriguez', 'Raul Chavez',
#         'A.J. Ellis', 'Brandon Inge', 'Pablo Sandoval', 'Jeff Mathis',
#         'Sal Fasano', 'Miguel Olivo', 'Rod Barajas', 'Josh Bard',
#         'Matt Treanor', 'Jamie Burke', 'Ryan Budde', 'Robinzon Diaz',
#         'Shawn Riggans', 'Luke Carlin', 'Jesus Flores', 'Mike Redmond',
#         'Adam Melhuse', 'Yadier Molina', 'Paul Lo Duca',
#         'Jarrod Saltalamacchia', 'Yorvit Torrealba', 'Kevin Cash',
#         'Jeff Clement', 'Javier Valentin', 'Johnny Estrada',
#         'Jorge Posada', 'Paul Hoover', 'Robby Hammock', 'J.R. Towles',
#         'Mike Rivera', 'Eliezer Alfonzo', 'Michael Barrett', 'Mike Rabelo',
#         'Corky Miller', 'Raul Casanova', 'Gary Bennett', 'Matt Tupman',
#         'Colt Morton', 'Gustavo Molina', 'Mike DiFelice', 'Austin Nola',
#         'Danny Jansen', 'Willson Contreras', 'Curt Casali',
#         'Tyler Flowers', 'Martín Maldonado', 'Jacob Nottingham',
#         'Yasmani Grandal', 'Alex Avila', 'Sean Murphy', 'Austin Barnes',
#         'Tony Wolters', 'Chance Sisco', 'Chad Wallach', 'Dustin Garneau',
#         'Joey Bart', 'Tyler Heineman', 'Daulton Varsho', 'James McCann',
#         "Travis d'Arnaud", 'Ryan Jeffers', 'Salvador Perez', 'Eric Haase',
#         'Pedro Severino', 'Jonah Heim', 'Robinson Chirinos',
#         'Wilson Ramos', 'Gary Sánchez', 'Jorge Alfaro', 'Max Stassi',
#         'Kevin Plawecki', 'Jacob Stallings', 'Sandy León', 'Andrew Knapp',
#         'Michael Pérez', 'Elias Díaz', 'Will Smith', 'Austin Romine',
#         'Christian Vázquez', 'Yan Gomes', 'Victor Caratini',
#         'Tucker Barnhart', 'Sam Huff', 'Carson Kelly', 'Luis Torrens',
#         'Kevan Smith', 'Alejandro Kirk', 'J.T. Realmuto', 'Mike Zunino',
#         'Anthony Bemboom', 'Joseph Odom', 'John Ryan Murphy',
#         'Omar Narváez', 'Drew Butera', 'Roberto Pérez', 'Mitch Garver',
#         'Rafael Marchán', 'Matt Wieters', 'Jason Castro',
#         'Kyle Higashioka', 'Tyler Stephenson', 'Willians Astudillo',
#         'Stephen Vogt', 'Austin Hedges', 'Grayson Greiner', 'Jose Trevino',
#         'Caleb Joseph', 'Cam Gallagher', 'José Briceño', 'Erik Kratz',
#         'Reese McGuire', 'Bryan Holaday', 'Ali Sánchez', 'Garrett Stubbs',
#         'Meibrys Viloria', 'Beau Taylor', 'Brian Navarreto',
#         'Josh Phegley', 'Keibert Ruiz', 'Manny Piña', 'Zack Collins',
#         'Tomás Nido', 'Andrew Knizner', 'Francisco Mejía',
#         'Ryan Lavarnway', 'Austin Allen', 'Chadwick Tromp', 'Joe Hudson',
#         'Alex Jackson', 'William Contreras', 'Rob Brantly', 'Taylor Ward',
#         'Rocky Gale', 'MJ Melendez', 'Webster Rivas', 'Buster Posey',
#         'Nick Fortes', 'Riley Adams', 'Taylor Davis', 'Nick Ciuffo',
#         'Tom Murphy', 'Austin Wynns', 'Cal Raleigh', 'Sebastián  Rivero',
#         'Dom Nuñez', 'Luke Maile', 'Payton Henry', 'Yohel Pozo',
#         'Ben Rortvedt', 'Seby Zavala', 'Patrick Mazeika', 'Tres Barrera',
#         'René Rivera', 'Jake Rogers', 'John Hicks', 'Jonathan Lucroy',
#         'Aramis Garcia', 'Connor Wong', 'Jose Lobaton', 'José Godoy',
#         'P.J. Higgins', 'Yermín Mercedes', 'Luis Campusano',
#         'Eli Whiteside', 'Bobby Wilson', 'Wyatt Toregas', 'Brayan Peña',
#         'Omir Santos', 'Chris Gimenez', 'Craig Tatum', 'Jake Fox',
#         'Landon Powell', 'Jose Morales', 'Jason Jaramillo',
#         'Paul Phillips', 'Devin Mesoraco', 'Bryan Anderson',
#         'Damaso Espino', 'Mark Wagner', 'Miguel Fermin', 'Dusty Brown',
#         'Jeff Christy', 'Mitch Canham', 'John Hester', 'Jonathon Fixler',
#         'Logan Moro', "Logan O'Hoppe", 'Patrick Bailey', 'Gabriel Moreno',
#         'Iván Herrera', 'Logan Porter', 'Carlos Pérez', 'Bo Naylor',
#         'Austin Wells', 'Jason Delay', 'Korey Lee', 'Brett Sullivan',
#         'Tyler Soderstrom', 'Endy Rodríguez', 'Christian Bethancourt',
#         'Francisco Alvarez', 'Yainer Diaz', 'Blake Sabol', 'David Fry',
#         'Adley Rutschman', 'René Pinto', 'Tyler Cropley',
#         'Shea Langeliers', 'Drew Millas', 'Miguel Amaya', 'Jose Herrera',
#         "Brian O'Keefe", 'Freddy Fermin', 'Matt Thaiss', 'Henry Davis',
#         'Brian Serven', 'César Salazar', 'Caleb Hamilton',
#         'Chuckie Robinson', 'Israel Pineda', 'Cooper Hummel',
#         'Michael Papierski', 'Mark Kolozsvary', 'Chris Okey',
#         'Bryan Lavastida', 'Roberto Alvarez', 'Rusber Estrada',
#         'Andy Yerzy', 'Xavier Fernández', 'Josh Crouch', 'Ian Moller',
#         'Juan Garcia', 'David Freitas', 'Juan Graterol', 'Roldani Baldwin',
#         'Juan Centeno', 'Colby Fitch', 'Hayden Senger',
#         'Welington Castillo', 'Tim Federowicz', 'Nick Dini', 'Raudy Read',
#         'Chris Herrmann', 'Kyle Farmer', 'Isiah Kiner-Falefa',
#         'Jesús Sucre', 'Blake Swihart', 'Spencer Kieboom',
#         'Francisco Arcia', 'Adam Moore', 'Francisco Peña', 'Raffy Lopez',
#         'Alfredo González', 'Bruce Maxwell', 'Andrew Susac', 'Jett Bandy',
#         'Steven Baron', 'Tony Cruz', 'Tomás Telis', 'Mike Marjama',
#         'Chris Stewart', 'Shawn Wooten', 'Damian Miller',
#         'Sandy Alomar Jr.', 'Héctor Ortiz', 'Einar Díaz', 'Joe Oliver',
#         'Mike Piazza', 'John Flaherty', 'Robert Fick', 'Benito Santiago',
#         'Tom Lampkin', 'Mike Matheny', 'Greg Myers', 'Jorge Fabregas',
#         'A.J. Hinch', 'Doug Mirabelli', 'Tony Eusebio', 'Todd Hundley',
#         'Josh Paul', 'Craig Wilson', 'Randy Knorr', 'Darrin Fletcher',
#         'Ben Davis', 'Charles Johnson', 'Brent Mayne', 'Bobby Estalella',
#         'Tom Wilson', 'Eli Marrero', 'Dan Wilson', 'Brook Fordyce',
#         'Joe Girardi', 'Fernando Lunar', 'Alberto Castillo', 'Javy Lopez',
#         'Chad Kreuter', 'Ben Petrick', 'Keith Osik', 'Eddie Taubensee',
#         'Kelly Stinnett', 'Todd Pratt', 'Tom Prince', 'Scott Hatteberg',
#         'Mike Hubbard', 'Angel Pena', 'Mike Lieberthal', 'Brian Johnson',
#         'Mike Kinkade', 'Javier Cardona', 'Wiki Gonzalez',
#         'Sandy Martinez', 'Cameron Rupp', 'Eric Fryer', 'Steve Clevenger',
#         'Travis Tartamella', 'Hank Conger', 'Trevor Brown', 'Derek Norris',
#         'Nevin Ashley', 'J.P. Arencibia', 'Carson Blair', 'Kyle Schwarber',
#         'Anthony Recker', 'Ramón Cabrera', 'Jackson Williams',
#         'Josh Thole', 'Héctor Sánchez', 'Óscar Hernández',
#         'Michael McKenry', 'Johnny Monell', 'Carlos Corporán', 'Ed Easley',
#         'Jordan Pacheco', 'Jhonatan Solano', 'Tuffy Gosewisch',
#         'Brett Hayes', 'Tony Sanchez', 'J.C. Boscan', 'José Yépez',
#         'Brandon Bantz', 'Joel Jimenez', 'René García', 'Shawn Zarraga',
#         'Wilkin Castillo', 'Jack Murphy', 'Evan Gattis', 'Josmil Pinto',
#         'Adrian Nieto', 'Wilin Rosario', 'Dan Butler', 'Matt Pagnozzi',
#         'John Jaso', 'Carlos Santana', 'Scott Servais', 'Mitch Meluskey',
#         'Carlos Hernandez', 'Jeff Reed', 'Matt Walbeck', 'Matthew LeCroy',
#         'Vance Wilson', 'Yohanny Valera', 'Kevin Brown', 'Bill Haselman',
#         'Mike Mahoney', 'Willie Morales', 'Chris Turner',
#         'George Williams', 'B.J. Waszgis', 'Lenny Webster', 'Chris Widger',
#         'Rick Wilkins', 'Marcus Jensen', 'Keith McDonald', 'Jim Leyritz',
#         'Charlie Greene', 'Tyler Houston', 'Todd Greene',
#         "Charlie O'Brien", 'Eddie Pérez', 'Alberto Rosario',
#         'Matt McBride', 'Brett Nicholas', 'Wilkyns Jimenez',
#         'Parker Berberet', 'Mac James', 'Jason Phillips',
#         'Steve Torrealba', 'Ken Huckaby', 'Humberto Cota',
#         'Robert Machado', 'Geronimo Gil', 'Trey Lunsford', 'Pat Borders',
#         'Walt McKeel', 'Juan Brito', 'Izzy Molina', 'Tom Gregorio',
#         'Pete Laforest', 'Miguel Ojeda', 'Tim Laker', 'Mandy Romero',
#         'Stuart Turner', 'A.J. Jimenez', 'Mike Ohlman', 'Eduardo Escobar',
#         'Tyler Marlette', 'Miguel Gonzalez', 'Cody Clark',
#         'Hector Gimenez', 'Steven Lerud', 'Jesus Montero', 'Blake Lalli',
#         'Carlos Maldonado', 'J.R. House', 'Donny Lucy', 'Chris Heintz',
#         'Eric Munson', 'Guillermo Rodriguez', 'Josh Phelps', 'Pedro Feliz',
#         'Mike Nickeas', 'Ali Solis', 'Vinny Rottino', 'Luis Martinez',
#         'Eddy Rodriguez', 'Josh Donaldson', 'Brandon Snyder',
#         'Luis Exposito', 'Zach Zaneski', 'Mark Fleury', 'Andrew Widell',
#         'Sean Ochinko', 'Jose Heberto Felix', 'Jake DePew', 'JD Closser',
#         'Josh Willingham', 'Mike Tonis', 'Cody McKay', 'Andy Dominique',
#         'Chris Shelton', 'Brian Esposito', 'Lucas May', 'Brad Davis',
#         'Robert Lara', 'Kyle Phillips', 'Elio Sarmiento', 'Chris Hatcher',
#         'P.J. Pilittere', 'Danny Lehmann', 'Adam Donachie', 'Yamid Haad',
#         'Ryan Jorgensen', 'Mike Rose'], dtype=object),
#  514)

# %%
cleaned_mlb[cleaned_mlb['credit']=='A.J. Pierzynski'].shape
# Out:
# (1212, 14)

# %%
catcher_names = cleaned_mlb['credit'].unique().tolist()

for catcher in catcher_names:
    catcher_df = cleaned_mlb.loc[cleaned_mlb['credit']==catcher]
    clean_catcher_name = str(catcher).replace(" ", "_") # can't have spaces between the names yo
    catcher_df.to_csv(f"{clean_catcher_name}.csv", index=False)

# %%
Pier = pd.read_csv('A.J._Pierzynski.csv')
Pier.shape
# Out:
# (1212, 14)

# %%
Pier.head()
# Out:
#   Start_Base End_Base           Event  runner_id         runner_name  \
# 0         1B       2B  Stolen Base 2B     122111      Gary Sheffield
# 1         1B       2B  Stolen Base 2B     434158   Curtis Granderson
# 2         1B       2B  Stolen Base 2B     430605         Ryan Raburn
# 3         1B       2B  Stolen Base 2B     434158   Curtis Granderson
# 4         1B       2B  Stolen Base 2B     429711  Franklin Gutierrez
#
#             credit  homeScore  awayScore  inning  isTopInning        Date  \
# 0  A.J. Pierzynski          0          0       1         True  2008-09-29
# 1  A.J. Pierzynski          1          0       3         True  2008-09-29
# 2  A.J. Pierzynski          1          1       5         True  2008-09-29
# 3  A.J. Pierzynski          6          2       7         True  2008-09-29
# 4  A.J. Pierzynski          0          2       2         True  2008-09-26
#
#    Action Base  Year
# 0  Stolen   2B  2008
# 1  Stolen   2B  2008
# 2  Stolen   2B  2008
# 3  Stolen   2B  2008
# 4  Stolen   2B  2008
